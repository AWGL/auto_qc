# %%
from interop import py_interop_run_metrics, py_interop_run, py_interop_summary
import pandas as pd
import math

# %%
def parse_interop_data(run_folder, num_reads, num_lanes):
    """
    Parses summary statistics out of interops data using the Illumina interops package
    """

    # make empty dict to store output
    interop_dict = {'read_summaries': {}}

    
    # taken from illumina interops package documentation, all of this is required, 
    # even though only the summary variable is used further on
    run_metrics = py_interop_run_metrics.run_metrics()
    valid_to_load = py_interop_run.uchar_vector(py_interop_run.MetricCount, 0)
    py_interop_run_metrics.list_summary_metrics_to_load(valid_to_load)
    run_folder = run_metrics.read(run_folder, valid_to_load)
    summary = py_interop_summary.run_summary()
    py_interop_summary.summarize_run_metrics(run_metrics, summary)
    

    
    for read in range(num_reads):
        
        new_read = read + 1
        
        if new_read not in interop_dict['read_summaries']:
            
            interop_dict['read_summaries'][new_read] = {}
        
            
        for lane in range(num_lanes):
            
            new_lane = lane + 1
                
            if new_lane not in interop_dict['read_summaries'][new_read]:
                    
                interop_dict['read_summaries'][new_read][new_lane] = {}
                    
            interop_dict['read_summaries'][read+1][lane+1]['percent_q30'] = summary.at(read).at(lane).percent_gt_q30()
            interop_dict['read_summaries'][read+1][lane+1]['density'] = summary.at(read).at(lane).density().mean()
            interop_dict['read_summaries'][read+1][lane+1]['density_pf'] = summary.at(read).at(lane).density_pf().mean()
            interop_dict['read_summaries'][read+1][lane+1]['cluster_count'] = summary.at(read).at(lane).density_pf().mean()
            interop_dict['read_summaries'][read+1][lane+1]['cluster_count_pf'] = summary.at(read).at(lane).cluster_count_pf().mean()
            interop_dict['read_summaries'][read+1][lane+1]['error_rate'] = summary.at(read).at(lane).error_rate().mean()
            interop_dict['read_summaries'][read+1][lane+1]['percent_aligned'] = summary.at(read).at(lane).percent_aligned().mean()
            interop_dict['read_summaries'][read+1][lane+1]['percent_pf'] = summary.at(read).at(lane).percent_pf().mean()
            interop_dict['read_summaries'][read+1][lane+1]['phasing'] = summary.at(read).at(lane).phasing().mean()
            interop_dict['read_summaries'][read+1][lane+1]['prephasing'] = summary.at(read).at(lane).prephasing().mean()
            interop_dict['read_summaries'][read+1][lane+1]['reads'] = summary.at(read).at(lane).reads()
            interop_dict['read_summaries'][read+1][lane+1]['reads_pf'] = summary.at(read).at(lane).reads_pf()
            interop_dict['read_summaries'][read+1][lane+1]['yield'] = summary.at(read).at(lane).yield_g()

    return interop_dict

# %%
parse_interop_data('/media/joseph/Storage/data/archive/nextseq/190913_NB551319_0026_AHT5G5AFXY/', 4, 4)
# Out:
# {'read_summaries': {1: {1: {'percent_q30': 92.2387924194336,
#     'density': 244107.328125,
#     'density_pf': 214203.265625,
#     'cluster_count': 214203.265625,
#     'cluster_count_pf': 643285.3125,
#     'error_rate': 0.3278927803039551,
#     'percent_aligned': 0.9878919124603271,
#     'percent_pf': 87.7578353881836,
#     'phasing': 0.21830081939697266,
#     'prephasing': 0.11702568084001541,
#     'reads': 52782588.0,
#     'reads_pf': 46316548.0,
#     'yield': 3.473161220550537},
#    2: {'percent_q30': 92.34395599365234,
#     'density': 234868.71875,
#     'density_pf': 207354.796875,
#     'cluster_count': 207354.796875,
#     'cluster_count_pf': 622718.25,
#     'error_rate': 0.4515427052974701,
#     'percent_aligned': 1.002793312072754,
#     'percent_pf': 88.27922058105469,
#     'phasing': 0.2153674066066742,
#     'prephasing': 0.1224762499332428,
#     'reads': 50784988.0,
#     'reads_pf': 44835700.0,
#     'yield': 3.3620235919952393},
#    3: {'percent_q30': 92.49681091308594,
#     'density': 247218.6875,
#     'density_pf': 218467.8125,
#     'cluster_count': 218467.8125,
#     'cluster_count_pf': 656092.4375,
#     'error_rate': 0.3737846910953522,
#     'percent_aligned': 0.9718897938728333,
#     'percent_pf': 88.37834930419922,
#     'phasing': 0.2152911126613617,
#     'prephasing': 0.12514585256576538,
#     'reads': 53455380.0,
#     'reads_pf': 47238640.0,
#     'yield': 3.542649030685425},
#    4: {'percent_q30': 92.6455307006836,
#     'density': 240472.4375,
#     'density_pf': 213057.40625,
#     'cluster_count': 213057.40625,
#     'cluster_count_pf': 639844.0,
#     'error_rate': 0.3127686381340027,
#     'percent_aligned': 0.9918357133865356,
#     'percent_pf': 88.59737396240234,
#     'phasing': 0.2136613428592682,
#     'prephasing': 0.12953706085681915,
#     'reads': 51996648.0,
#     'reads_pf': 46068780.0,
#     'yield': 3.4548606872558594}},
#   2: {1: {'percent_q30': 94.76021575927734,
#     'density': 244107.328125,
#     'density_pf': 214203.265625,
#     'cluster_count': 214203.265625,
#     'cluster_count_pf': 643285.3125,
#     'error_rate': nan,
#     'percent_aligned': nan,
#     'percent_pf': 87.7578353881836,
#     'phasing': nan,
#     'prephasing': nan,
#     'reads': 52782588.0,
#     'reads_pf': 46316548.0,
#     'yield': 0.3237026333808899},
#    2: {'percent_q30': 93.28593444824219,
#     'density': 234868.71875,
#     'density_pf': 207354.796875,
#     'cluster_count': 207354.796875,
#     'cluster_count_pf': 622718.25,
#     'error_rate': nan,
#     'percent_aligned': nan,
#     'percent_pf': 88.27922058105469,
#     'phasing': nan,
#     'prephasing': nan,
#     'reads': 50784988.0,
#     'reads_pf': 44835700.0,
#     'yield': 0.3133471608161926},
#    3: {'percent_q30': 94.5661392211914,
#     'density': 247218.6875,
#     'density_pf': 218467.8125,
#     'cluster_count': 218467.8125,
#     'cluster_count_pf': 656092.4375,
#     'error_rate': nan,
#     'percent_aligned': nan,
#     'percent_pf': 88.37834930419922,
#     'phasing': nan,
#     'prephasing': nan,
#     'reads': 53455380.0,
#     'reads_pf': 47238640.0,
#     'yield': 0.3303540050983429},
#    4: {'percent_q30': 94.27381896972656,
#     'density': 240472.4375,
#     'density_pf': 213057.40625,
#     'cluster_count': 213057.40625,
#     'cluster_count_pf': 639844.0,
#     'error_rate': nan,
#     'percent_aligned': nan,
#     'percent_pf': 88.59737396240234,
#     'phasing': nan,
#     'prephasing': nan,
#     'reads': 51996648.0,
#     'reads_pf': 46068780.0,
#     'yield': 0.3221604526042938}},
#   3: {1: {'percent_q30': 94.36151885986328,
#     'density': 244107.328125,
#     'density_pf': 214203.265625,
#     'cluster_count': 214203.265625,
#     'cluster_count_pf': 643285.3125,
#     'error_rate': nan,
#     'percent_aligned': nan,
#     'percent_pf': 87.7578353881836,
#     'phasing': nan,
#     'prephasing': nan,
#     'reads': 52782588.0,
#     'reads_pf': 46316548.0,
#     'yield': 0.32399919629096985},
#    2: {'percent_q30': 93.49507141113281,
#     'density': 234868.71875,
#     'density_pf': 207354.796875,
#     'cluster_count': 207354.796875,
#     'cluster_count_pf': 622718.25,
#     'error_rate': nan,
#     'percent_aligned': nan,
#     'percent_pf': 88.27922058105469,
#     'phasing': nan,
#     'prephasing': nan,
#     'reads': 50784988.0,
#     'reads_pf': 44835700.0,
#     'yield': 0.3136111795902252},
#    3: {'percent_q30': 94.16024780273438,
#     'density': 247218.6875,
#     'density_pf': 218467.8125,
#     'cluster_count': 218467.8125,
#     'cluster_count_pf': 656092.4375,
#     'error_rate': nan,
#     'percent_aligned': nan,
#     'percent_pf': 88.37834930419922,
#     'phasing': nan,
#     'prephasing': nan,
#     'reads': 53455380.0,
#     'reads_pf': 47238640.0,
#     'yield': 0.33048397302627563},
#    4: {'percent_q30': 94.52648162841797,
#     'density': 240472.4375,
#     'density_pf': 213057.40625,
#     'cluster_count': 213057.40625,
#     'cluster_count_pf': 639844.0,
#     'error_rate': nan,
#     'percent_aligned': nan,
#     'percent_pf': 88.59737396240234,
#     'phasing': nan,
#     'prephasing': nan,
#     'reads': 51996648.0,
#     'reads_pf': 46068780.0,
#     'yield': 0.3223322331905365}},
#   4: {1: {'percent_q30': 88.30977630615234,
#     'density': 244107.328125,
#     'density_pf': 214203.265625,
#     'cluster_count': 214203.265625,
#     'cluster_count_pf': 643285.3125,
#     'error_rate': 0.4178047478199005,
#     'percent_aligned': 0.9585206508636475,
#     'percent_pf': 87.7578353881836,
#     'phasing': 0.2452705204486847,
#     'prephasing': 0.16752710938453674,
#     'reads': 52782588.0,
#     'reads_pf': 46316548.0,
#     'yield': 3.470811605453491},
#    2: {'percent_q30': 87.2183609008789,
#     'density': 234868.71875,
#     'density_pf': 207354.796875,
#     'cluster_count': 207354.796875,
#     'cluster_count_pf': 622718.25,
#     'error_rate': 0.554936408996582,
#     'percent_aligned': 0.9543738961219788,
#     'percent_pf': 88.27922058105469,
#     'phasing': 0.23730047047138214,
#     'prephasing': 0.175917848944664,
#     'reads': 50784988.0,
#     'reads_pf': 44835700.0,
#     'yield': 3.360084056854248},
#    3: {'percent_q30': 88.28157806396484,
#     'density': 247218.6875,
#     'density_pf': 218467.8125,
#     'cluster_count': 218467.8125,
#     'cluster_count_pf': 656092.4375,
#     'error_rate': 0.4489757716655731,
#     'percent_aligned': 0.9388121366500854,
#     'percent_pf': 88.37834930419922,
#     'phasing': 0.24369245767593384,
#     'prephasing': 0.1616465151309967,
#     'reads': 53455380.0,
#     'reads_pf': 47238640.0,
#     'yield': 3.5417869091033936},
#    4: {'percent_q30': 88.30270385742188,
#     'density': 240472.4375,
#     'density_pf': 213057.40625,
#     'cluster_count': 213057.40625,
#     'cluster_count_pf': 639844.0,
#     'error_rate': 0.42395976185798645,
#     'percent_aligned': 0.9598789215087891,
#     'percent_pf': 88.59737396240234,
#     'phasing': 0.2436690628528595,
#     'prephasing': 0.1681184470653534,
#     'reads': 51996648.0,
#     'reads_pf': 46068780.0,
#     'yield': 3.4541707038879395}}}}

# %%
run_folder ='/media/joseph/Storage/data/archive/miseq/190916_M00766_0252_000000000-CJMB5'

run_metrics = py_interop_run_metrics.run_metrics()
valid_to_load = py_interop_run.uchar_vector(py_interop_run.MetricCount, 0)
py_interop_run_metrics.list_index_metrics_to_load(valid_to_load)
run_folder = run_metrics.read(run_folder, valid_to_load)
summary = py_interop_summary.index_flowcell_summary()
py_interop_summary.summarize_index_metrics(run_metrics, summary)

# %%
n_lanes = 1

columns = ( ('Index Number', 'id'), ('Sample Id', 'sample_id'), ('Project', 'project_name'), ('Index 1 (I7)', 'index1'), ('Index 2 (I5)', 'index2'), ('% Reads Identified (PF)', 'fraction_mapped'))

df = pd.DataFrame()

for x in range(0, n_lanes):
    
    d = []
    
    for label, func in columns:

        lane_summary = summary.at(x)

        d.append( (label, pd.Series([getattr(lane_summary.at(i), func)() for i in range(lane_summary.size())], index=[lane_summary.at(i).id() for i in range(lane_summary.size())])))

    new_df = pd.DataFrame.from_dict(dict(d))
    new_df['lane'] = x

    df = df.append(new_df )

# %%
df_grouped = df.groupby('Sample Id').mean()

# %%
#df_grouped.to_dict('index')

# %%
index_dict = df.to_dict('records')

# %%
def parse_interop_index_metrics(run_folder, n_lanes):
    """
    Get the index stats from the interop files

    """

    run_metrics = py_interop_run_metrics.run_metrics()
    valid_to_load = py_interop_run.uchar_vector(py_interop_run.MetricCount, 0)
    py_interop_run_metrics.list_index_metrics_to_load(valid_to_load)
    run_folder = run_metrics.read(run_folder, valid_to_load)
    my_summary = py_interop_summary.index_flowcell_summary()
    py_interop_summary.summarize_index_metrics(run_metrics, my_summary)

    columns = ( ('Index Number', 'id'),
    ('Sample Id', 'sample_id'),
    ('Project', 'project_name'),
    ('Index 1 (I7)', 'index1'),
    ('Index 2 (I5)', 'index2'),
    ('% Reads Identified (PF)', 'fraction_mapped'))

    df = pd.DataFrame()

    for x in range(0, n_lanes):

        d = []

        for label, func in columns:

            lane_summary = summary.at(x)

            d.append( (label, pd.Series([getattr(lane_summary.at(i), func)() for i in range(lane_summary.size())], index=[lane_summary.at(i).id() for i in range(lane_summary.size())])))

        new_df = pd.DataFrame.from_dict(dict(d))
        new_df['lane'] = x

        df = df.append(new_df )

    df_grouped = df.groupby('Sample Id').mean()

    index_dict = df_grouped.to_dict('index')

    return index_dict

# %%
parse_interop_index_metrics('/media/joseph/Storage/data/archive/miseq/190916_M00766_0252_000000000-CJMB5', 1)
# Out:
# {'19M12481': {'Index Number': 1,
#   '% Reads Identified (PF)': 4.841100215911865,
#   'lane': 0},
#  '19M12638': {'Index Number': 2,
#   '% Reads Identified (PF)': 4.885499954223633,
#   'lane': 0},
#  '19M13283': {'Index Number': 3,
#   '% Reads Identified (PF)': 5.553899765014648,
#   'lane': 0},
#  '19M13333': {'Index Number': 4,
#   '% Reads Identified (PF)': 4.89139986038208,
#   'lane': 0},
#  '19M13455': {'Index Number': 5,
#   '% Reads Identified (PF)': 5.307199954986572,
#   'lane': 0},
#  '19M13506': {'Index Number': 6,
#   '% Reads Identified (PF)': 3.9500999450683594,
#   'lane': 0},
#  '19M13507': {'Index Number': 7,
#   '% Reads Identified (PF)': 4.873499870300293,
#   'lane': 0},
#  '19M13508': {'Index Number': 8,
#   '% Reads Identified (PF)': 4.499599933624268,
#   'lane': 0},
#  '19M13509': {'Index Number': 9,
#   '% Reads Identified (PF)': 4.046999931335449,
#   'lane': 0},
#  '19M13510': {'Index Number': 10,
#   '% Reads Identified (PF)': 4.175099849700928,
#   'lane': 0},
#  '19M13511': {'Index Number': 11,
#   '% Reads Identified (PF)': 4.055799961090088,
#   'lane': 0},
#  '19M13512': {'Index Number': 12,
#   '% Reads Identified (PF)': 3.8896000385284424,
#   'lane': 0},
#  '19M13513': {'Index Number': 13,
#   '% Reads Identified (PF)': 3.4818999767303467,
#   'lane': 0},
#  '19M13514': {'Index Number': 14,
#   '% Reads Identified (PF)': 3.395699977874756,
#   'lane': 0},
#  '19M13533': {'Index Number': 15,
#   '% Reads Identified (PF)': 3.5713999271392822,
#   'lane': 0},
#  '19M13692': {'Index Number': 16,
#   '% Reads Identified (PF)': 3.314300060272217,
#   'lane': 0},
#  '19M13693': {'Index Number': 17,
#   '% Reads Identified (PF)': 4.584700107574463,
#   'lane': 0},
#  '19M13694': {'Index Number': 18,
#   '% Reads Identified (PF)': 3.7327001094818115,
#   'lane': 0},
#  '19M13695': {'Index Number': 19,
#   '% Reads Identified (PF)': 4.189599990844727,
#   'lane': 0},
#  '19M13709': {'Index Number': 20,
#   '% Reads Identified (PF)': 4.054999828338623,
#   'lane': 0},
#  '19M13713': {'Index Number': 21,
#   '% Reads Identified (PF)': 4.2778000831604,
#   'lane': 0},
#  '19M14004': {'Index Number': 22,
#   '% Reads Identified (PF)': 3.770699977874756,
#   'lane': 0},
#  '19M14076': {'Index Number': 23,
#   '% Reads Identified (PF)': 4.0157999992370605,
#   'lane': 0},
#  'NTC': {'Index Number': 24,
#   '% Reads Identified (PF)': 0.009100000374019146,
#   'lane': 0}}

# %%
def parse_interop_data(run_folder_dir, num_reads, num_lanes):
    """
    Parses summary statistics out of interops data using the Illumina interops package
    """

    # make empty dict to store output
    interop_dict = {'read_summaries': {}}


    # taken from illumina interops package documentation, all of this is required, 
    # even though only the summary variable is used further on
    run_metrics = py_interop_run_metrics.run_metrics()
    valid_to_load = py_interop_run.uchar_vector(py_interop_run.MetricCount, 0)
    py_interop_run_metrics.list_summary_metrics_to_load(valid_to_load)
    run_folder = run_metrics.read(run_folder_dir, valid_to_load)
    summary = py_interop_summary.run_summary()
    py_interop_summary.summarize_run_metrics(run_metrics, summary)


    for read in range(num_reads):

        new_read = read + 1

        if new_read not in interop_dict['read_summaries']:

            interop_dict['read_summaries'][new_read] = {}


        for lane in range(num_lanes):

            new_lane = lane + 1

            if new_lane not in interop_dict['read_summaries'][new_read]:

                interop_dict['read_summaries'][new_read][new_lane] = {}

            interop_dict['read_summaries'][read+1][lane+1]['percent_q30'] = summary.at(read).at(lane).percent_gt_q30()
            interop_dict['read_summaries'][read+1][lane+1]['density'] = summary.at(read).at(lane).density().mean()
            interop_dict['read_summaries'][read+1][lane+1]['density_pf'] = summary.at(read).at(lane).density_pf().mean()
            interop_dict['read_summaries'][read+1][lane+1]['cluster_count'] = summary.at(read).at(lane).density_pf().mean()
            interop_dict['read_summaries'][read+1][lane+1]['cluster_count_pf'] = summary.at(read).at(lane).cluster_count_pf().mean()
            interop_dict['read_summaries'][read+1][lane+1]['error_rate'] = summary.at(read).at(lane).error_rate().mean()
            interop_dict['read_summaries'][read+1][lane+1]['percent_aligned'] = summary.at(read).at(lane).percent_aligned().mean()
            interop_dict['read_summaries'][read+1][lane+1]['percent_pf'] = summary.at(read).at(lane).percent_pf().mean()
            interop_dict['read_summaries'][read+1][lane+1]['phasing'] = summary.at(read).at(lane).phasing().mean()
            interop_dict['read_summaries'][read+1][lane+1]['prephasing'] = summary.at(read).at(lane).prephasing().mean()
            interop_dict['read_summaries'][read+1][lane+1]['reads'] = summary.at(read).at(lane).reads()
            interop_dict['read_summaries'][read+1][lane+1]['reads_pf'] = summary.at(read).at(lane).reads_pf()
            interop_dict['read_summaries'][read+1][lane+1]['yield_g'] = summary.at(read).at(lane).yield_g()

            for key in interop_dict['read_summaries'][read+1][lane+1]:

                if math.isnan(interop_dict['read_summaries'][read+1][lane+1][key]):

                    interop_dict['read_summaries'][read+1][lane+1][key] = None


    run_metrics = py_interop_run_metrics.run_metrics()
    valid_to_load = py_interop_run.uchar_vector(py_interop_run.MetricCount, 0)
    py_interop_run_metrics.list_index_metrics_to_load(valid_to_load)
    run_folder = run_metrics.read(run_folder_dir, valid_to_load)
    my_summary = py_interop_summary.index_flowcell_summary()
    py_interop_summary.summarize_index_metrics(run_metrics, my_summary)

    columns = ( ('Index Number', 'id'),
    ('Sample Id', 'sample_id'),
    ('Project', 'project_name'),
    ('Index 1 (I7)', 'index1'),
    ('Index 2 (I5)', 'index2'),
    ('% Reads Identified (PF)', 'fraction_mapped'))

    df = pd.DataFrame()

    for x in range(num_lanes):

        d = []

        for label, func in columns:

            lane_summary = my_summary.at(x)

            d.append( (label, pd.Series([getattr(lane_summary.at(i), func)() for i in range(lane_summary.size())], index=[lane_summary.at(i).id() for i in range(lane_summary.size())])))

        new_df = pd.DataFrame.from_dict(dict(d))
        new_df['lane'] = x

        df = df.append(new_df )

    df_grouped = df.groupby('Sample Id').mean()

    index_dict = df_grouped.to_dict('index')

    interop_dict['index_stats'] = index_dict

    return interop_dict

# %%
parse_interop_data('/media/joseph/Storage/data/archive/nextseq/190913_NB551319_0026_AHT5G5AFXY/', 4, 4)
# Out:
# {'read_summaries': {1: {1: {'percent_q30': 92.2387924194336,
#     'density': 244107.328125,
#     'density_pf': 214203.265625,
#     'cluster_count': 214203.265625,
#     'cluster_count_pf': 643285.3125,
#     'error_rate': 0.3278927803039551,
#     'percent_aligned': 0.9878919124603271,
#     'percent_pf': 87.7578353881836,
#     'phasing': 0.21830081939697266,
#     'prephasing': 0.11702568084001541,
#     'reads': 52782588.0,
#     'reads_pf': 46316548.0,
#     'yield_g': 3.473161220550537},
#    2: {'percent_q30': 92.34395599365234,
#     'density': 234868.71875,
#     'density_pf': 207354.796875,
#     'cluster_count': 207354.796875,
#     'cluster_count_pf': 622718.25,
#     'error_rate': 0.4515427052974701,
#     'percent_aligned': 1.002793312072754,
#     'percent_pf': 88.27922058105469,
#     'phasing': 0.2153674066066742,
#     'prephasing': 0.1224762499332428,
#     'reads': 50784988.0,
#     'reads_pf': 44835700.0,
#     'yield_g': 3.3620235919952393},
#    3: {'percent_q30': 92.49681091308594,
#     'density': 247218.6875,
#     'density_pf': 218467.8125,
#     'cluster_count': 218467.8125,
#     'cluster_count_pf': 656092.4375,
#     'error_rate': 0.3737846910953522,
#     'percent_aligned': 0.9718897938728333,
#     'percent_pf': 88.37834930419922,
#     'phasing': 0.2152911126613617,
#     'prephasing': 0.12514585256576538,
#     'reads': 53455380.0,
#     'reads_pf': 47238640.0,
#     'yield_g': 3.542649030685425},
#    4: {'percent_q30': 92.6455307006836,
#     'density': 240472.4375,
#     'density_pf': 213057.40625,
#     'cluster_count': 213057.40625,
#     'cluster_count_pf': 639844.0,
#     'error_rate': 0.3127686381340027,
#     'percent_aligned': 0.9918357133865356,
#     'percent_pf': 88.59737396240234,
#     'phasing': 0.2136613428592682,
#     'prephasing': 0.12953706085681915,
#     'reads': 51996648.0,
#     'reads_pf': 46068780.0,
#     'yield_g': 3.4548606872558594}},
#   2: {1: {'percent_q30': 94.76021575927734,
#     'density': 244107.328125,
#     'density_pf': 214203.265625,
#     'cluster_count': 214203.265625,
#     'cluster_count_pf': 643285.3125,
#     'error_rate': None,
#     'percent_aligned': None,
#     'percent_pf': 87.7578353881836,
#     'phasing': None,
#     'prephasing': None,
#     'reads': 52782588.0,
#     'reads_pf': 46316548.0,
#     'yield_g': 0.3237026333808899},
#    2: {'percent_q30': 93.28593444824219,
#     'density': 234868.71875,
#     'density_pf': 207354.796875,
#     'cluster_count': 207354.796875,
#     'cluster_count_pf': 622718.25,
#     'error_rate': None,
#     'percent_aligned': None,
#     'percent_pf': 88.27922058105469,
#     'phasing': None,
#     'prephasing': None,
#     'reads': 50784988.0,
#     'reads_pf': 44835700.0,
#     'yield_g': 0.3133471608161926},
#    3: {'percent_q30': 94.5661392211914,
#     'density': 247218.6875,
#     'density_pf': 218467.8125,
#     'cluster_count': 218467.8125,
#     'cluster_count_pf': 656092.4375,
#     'error_rate': None,
#     'percent_aligned': None,
#     'percent_pf': 88.37834930419922,
#     'phasing': None,
#     'prephasing': None,
#     'reads': 53455380.0,
#     'reads_pf': 47238640.0,
#     'yield_g': 0.3303540050983429},
#    4: {'percent_q30': 94.27381896972656,
#     'density': 240472.4375,
#     'density_pf': 213057.40625,
#     'cluster_count': 213057.40625,
#     'cluster_count_pf': 639844.0,
#     'error_rate': None,
#     'percent_aligned': None,
#     'percent_pf': 88.59737396240234,
#     'phasing': None,
#     'prephasing': None,
#     'reads': 51996648.0,
#     'reads_pf': 46068780.0,
#     'yield_g': 0.3221604526042938}},
#   3: {1: {'percent_q30': 94.36151885986328,
#     'density': 244107.328125,
#     'density_pf': 214203.265625,
#     'cluster_count': 214203.265625,
#     'cluster_count_pf': 643285.3125,
#     'error_rate': None,
#     'percent_aligned': None,
#     'percent_pf': 87.7578353881836,
#     'phasing': None,
#     'prephasing': None,
#     'reads': 52782588.0,
#     'reads_pf': 46316548.0,
#     'yield_g': 0.32399919629096985},
#    2: {'percent_q30': 93.49507141113281,
#     'density': 234868.71875,
#     'density_pf': 207354.796875,
#     'cluster_count': 207354.796875,
#     'cluster_count_pf': 622718.25,
#     'error_rate': None,
#     'percent_aligned': None,
#     'percent_pf': 88.27922058105469,
#     'phasing': None,
#     'prephasing': None,
#     'reads': 50784988.0,
#     'reads_pf': 44835700.0,
#     'yield_g': 0.3136111795902252},
#    3: {'percent_q30': 94.16024780273438,
#     'density': 247218.6875,
#     'density_pf': 218467.8125,
#     'cluster_count': 218467.8125,
#     'cluster_count_pf': 656092.4375,
#     'error_rate': None,
#     'percent_aligned': None,
#     'percent_pf': 88.37834930419922,
#     'phasing': None,
#     'prephasing': None,
#     'reads': 53455380.0,
#     'reads_pf': 47238640.0,
#     'yield_g': 0.33048397302627563},
#    4: {'percent_q30': 94.52648162841797,
#     'density': 240472.4375,
#     'density_pf': 213057.40625,
#     'cluster_count': 213057.40625,
#     'cluster_count_pf': 639844.0,
#     'error_rate': None,
#     'percent_aligned': None,
#     'percent_pf': 88.59737396240234,
#     'phasing': None,
#     'prephasing': None,
#     'reads': 51996648.0,
#     'reads_pf': 46068780.0,
#     'yield_g': 0.3223322331905365}},
#   4: {1: {'percent_q30': 88.30977630615234,
#     'density': 244107.328125,
#     'density_pf': 214203.265625,
#     'cluster_count': 214203.265625,
#     'cluster_count_pf': 643285.3125,
#     'error_rate': 0.4178047478199005,
#     'percent_aligned': 0.9585206508636475,
#     'percent_pf': 87.7578353881836,
#     'phasing': 0.2452705204486847,
#     'prephasing': 0.16752710938453674,
#     'reads': 52782588.0,
#     'reads_pf': 46316548.0,
#     'yield_g': 3.470811605453491},
#    2: {'percent_q30': 87.2183609008789,
#     'density': 234868.71875,
#     'density_pf': 207354.796875,
#     'cluster_count': 207354.796875,
#     'cluster_count_pf': 622718.25,
#     'error_rate': 0.554936408996582,
#     'percent_aligned': 0.9543738961219788,
#     'percent_pf': 88.27922058105469,
#     'phasing': 0.23730047047138214,
#     'prephasing': 0.175917848944664,
#     'reads': 50784988.0,
#     'reads_pf': 44835700.0,
#     'yield_g': 3.360084056854248},
#    3: {'percent_q30': 88.28157806396484,
#     'density': 247218.6875,
#     'density_pf': 218467.8125,
#     'cluster_count': 218467.8125,
#     'cluster_count_pf': 656092.4375,
#     'error_rate': 0.4489757716655731,
#     'percent_aligned': 0.9388121366500854,
#     'percent_pf': 88.37834930419922,
#     'phasing': 0.24369245767593384,
#     'prephasing': 0.1616465151309967,
#     'reads': 53455380.0,
#     'reads_pf': 47238640.0,
#     'yield_g': 3.5417869091033936},
#    4: {'percent_q30': 88.30270385742188,
#     'density': 240472.4375,
#     'density_pf': 213057.40625,
#     'cluster_count': 213057.40625,
#     'cluster_count_pf': 639844.0,
#     'error_rate': 0.42395976185798645,
#     'percent_aligned': 0.9598789215087891,
#     'percent_pf': 88.59737396240234,
#     'phasing': 0.2436690628528595,
#     'prephasing': 0.1681184470653534,
#     'reads': 51996648.0,
#     'reads_pf': 46068780.0,
#     'yield_g': 3.4541707038879395}}},
#  'index_stats': {'19M13893': {'Index Number': 1.0,
#    '% Reads Identified (PF)': 2.46384996175766,
#    'lane': 1.5},
#   '19M13908': {'Index Number': 2.0,
#    '% Reads Identified (PF)': 2.6683249473571777,
#    'lane': 1.5},
#   '19M13909': {'Index Number': 3.0,
#    '% Reads Identified (PF)': 2.5399249792099,
#    'lane': 1.5},
#   '19M13916': {'Index Number': 4.0,
#    '% Reads Identified (PF)': 2.7798749804496765,
#    'lane': 1.5},
#   '19M13940': {'Index Number': 5.0,
#    '% Reads Identified (PF)': 2.604224979877472,
#    'lane': 1.5},
#   '19M13949': {'Index Number': 6.0,
#    '% Reads Identified (PF)': 2.289324998855591,
#    'lane': 1.5},
#   '19M13953': {'Index Number': 7.0,
#    '% Reads Identified (PF)': 2.608799934387207,
#    'lane': 1.5},
#   '19M13956': {'Index Number': 8.0,
#    '% Reads Identified (PF)': 2.59375,
#    'lane': 1.5},
#   '19M13957': {'Index Number': 9.0,
#    '% Reads Identified (PF)': 1.882275015115738,
#    'lane': 1.5},
#   '19M14006': {'Index Number': 10.0,
#    '% Reads Identified (PF)': 4.344974994659424,
#    'lane': 1.5},
#   '19M14027': {'Index Number': 11.0,
#    '% Reads Identified (PF)': 1.6679750084877014,
#    'lane': 1.5},
#   '19M14028': {'Index Number': 12.0,
#    '% Reads Identified (PF)': 1.8877750039100647,
#    'lane': 1.5},
#   '19M14029': {'Index Number': 13.0,
#    '% Reads Identified (PF)': 2.785474956035614,
#    'lane': 1.5},
#   '19M14030': {'Index Number': 14.0,
#    '% Reads Identified (PF)': 2.817425012588501,
#    'lane': 1.5},
#   '19M14034': {'Index Number': 15.0,
#    '% Reads Identified (PF)': 2.2731749415397644,
#    'lane': 1.5},
#   '19M14048': {'Index Number': 16.0,
#    '% Reads Identified (PF)': 2.2850500345230103,
#    'lane': 1.5},
#   '19M14051': {'Index Number': 17.0,
#    '% Reads Identified (PF)': 2.574100077152252,
#    'lane': 1.5},
#   '19M14052': {'Index Number': 18.0,
#    '% Reads Identified (PF)': 2.243874967098236,
#    'lane': 1.5},
#   '19M14057': {'Index Number': 19.0,
#    '% Reads Identified (PF)': 2.440149962902069,
#    'lane': 1.5},
#   '19M14064': {'Index Number': 20.0,
#    '% Reads Identified (PF)': 2.761675000190735,
#    'lane': 1.5},
#   '19M14069': {'Index Number': 21.0,
#    '% Reads Identified (PF)': 2.4025999903678894,
#    'lane': 1.5},
#   '19M14108': {'Index Number': 22.0,
#    '% Reads Identified (PF)': 2.654400050640106,
#    'lane': 1.5},
#   '19M14113': {'Index Number': 23.0,
#    '% Reads Identified (PF)': 2.1796250343322754,
#    'lane': 1.5},
#   '19M14135': {'Index Number': 24.0,
#    '% Reads Identified (PF)': 2.524025022983551,
#    'lane': 1.5},
#   '19M14179': {'Index Number': 25.0,
#    '% Reads Identified (PF)': 2.0708749890327454,
#    'lane': 1.5},
#   '19M14180': {'Index Number': 26.0,
#    '% Reads Identified (PF)': 1.7120000123977661,
#    'lane': 1.5},
#   '19M14181': {'Index Number': 27.0,
#    '% Reads Identified (PF)': 5.4451000690460205,
#    'lane': 1.5},
#   '19M14182': {'Index Number': 28.0,
#    '% Reads Identified (PF)': 1.4472750127315521,
#    'lane': 1.5},
#   '19M14183': {'Index Number': 29.0,
#    '% Reads Identified (PF)': 1.7447499930858612,
#    'lane': 1.5},
#   '19M14188': {'Index Number': 30.0,
#    '% Reads Identified (PF)': 3.152025043964386,
#    'lane': 1.5},
#   '19M14191': {'Index Number': 31.0,
#    '% Reads Identified (PF)': 2.760499954223633,
#    'lane': 1.5},
#   '19M14192': {'Index Number': 32.0,
#    '% Reads Identified (PF)': 2.3788999915122986,
#    'lane': 1.5},
#   '19M14194': {'Index Number': 33.0,
#    '% Reads Identified (PF)': 3.432550013065338,
#    'lane': 1.5},
#   '19M14212': {'Index Number': 34.0,
#    '% Reads Identified (PF)': 2.2070500254631042,
#    'lane': 1.5},
#   '19M14214': {'Index Number': 35.0,
#    '% Reads Identified (PF)': 2.172599971294403,
#    'lane': 1.5},
#   '19M14218': {'Index Number': 36.0,
#    '% Reads Identified (PF)': 3.098699986934662,
#    'lane': 1.5},
#   'NTC': {'Index Number': 37.0,
#    '% Reads Identified (PF)': 0.00039999998989515007,
#    'lane': 1.5}}}
